# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from sklearn.model_selection import train_test_split
import re
import seaborn as sns
import matplotlib.pyplot as plt


import nltk
nltk.download("stopwords")
from nltk.stem.porter import *
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

pd.options.plotting.backend = "plotly"

from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ismaelegorgoglione/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("../Dataset/new_data.csv", encoding="ISO-8859-1")

# %% [markdown]
# # Preprocessing

# %%
tfidfconverter = CountVectorizer(max_features=5000, min_df=10, stop_words="english", lowercase=True)
X = tfidfconverter.fit_transform(df["news"]).toarray()

# %% [markdown]
# ### Train & Test Split

# %%
y = pd.get_dummies(df['sentiment'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1)
print('Train Set ->', X_train.shape, y_train.shape)
print('Validation Set ->', X_val.shape, y_val.shape)
print('Test Set ->', X_test.shape, y_test.shape)
# Out:
# Train Set -> (2541, 1007) (2541, 3)
# Validation Set -> (847, 1007) (847, 3)
# Test Set -> (1452, 1007) (1452, 3)

# %%
import keras.backend as K

def f1_score(precision, recall):
    ''' Function to calculate f1 score '''
    
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# ## Bidirectional LSTM Using NN

# %%
vocab_size = 5000
embedding_size = 32
epochs=50
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
# Build model
model= Sequential()
model.add(Embedding(vocab_size, embedding_size))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.4))
model.add(Dense(3, activation='softmax'))
# Out:
# 2022-12-07 15:47:45.788474: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          160000
#
#  conv1d (Conv1D)             (None, None, 32)          3104
#
#  max_pooling1d (MaxPooling1D  (None, None, 32)         0
#  )
#
#  bidirectional (Bidirectiona  (None, 64)               16640
#  l)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 179,939
# Trainable params: 179,939
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
               metrics=['accuracy', Precision(), Recall()])

# Train model

batch_size = 64
history = model.fit(X_train, y_train,
                      validation_data=(X_val, y_val),
                      batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 19s 367ms/step - loss: 0.9869 - accuracy: 0.5844 - precision: 0.5915 - recall: 0.3026 - val_loss: 0.9255 - val_accuracy: 0.6009 - val_precision: 0.6009 - val_recall: 0.6009
# Epoch 2/50
# 40/40 [==============================] - 14s 341ms/step - loss: 0.9376 - accuracy: 0.5903 - precision: 0.6013 - recall: 0.5293 - val_loss: 0.9247 - val_accuracy: 0.6009 - val_precision: 0.6009 - val_recall: 0.6009
# Epoch 3/50
# 40/40 [==============================] - 16s 394ms/step - loss: 0.9298 - accuracy: 0.5907 - precision: 0.6022 - recall: 0.5506 - val_loss: 0.9051 - val_accuracy: 0.6021 - val_precision: 0.6204 - val_recall: 0.5962
# Epoch 4/50
# 40/40 [==============================] - 18s 460ms/step - loss: 0.9154 - accuracy: 0.5990 - precision: 0.6184 - recall: 0.5490 - val_loss: 0.9024 - val_accuracy: 0.6175 - val_precision: 0.6819 - val_recall: 0.4404
# Epoch 5/50
# 40/40 [==============================] - 18s 434ms/step - loss: 0.9151 - accuracy: 0.5962 - precision: 0.6370 - recall: 0.4648 - val_loss: 0.8762 - val_accuracy: 0.6234 - val_precision: 0.6821 - val_recall: 0.5218
# Epoch 6/50
# 40/40 [==============================] - 14s 360ms/step - loss: 0.9024 - accuracy: 0.5986 - precision: 0.6382 - recall: 0.5053 - val_loss: 0.8732 - val_accuracy: 0.6210 - val_precision: 0.6824 - val_recall: 0.5277
# Epoch 7/50
# 40/40 [==============================] - 14s 357ms/step - loss: 0.9040 - accuracy: 0.6017 - precision: 0.6415 - recall: 0.5085 - val_loss: 0.8748 - val_accuracy: 0.6234 - val_precision: 0.6817 - val_recall: 0.5159
# Epoch 8/50
# 40/40 [==============================] - 16s 400ms/step - loss: 0.9073 - accuracy: 0.6021 - precision: 0.6449 - recall: 0.5018 - val_loss: 0.8709 - val_accuracy: 0.6175 - val_precision: 0.6798 - val_recall: 0.5289
# Epoch 9/50
# 40/40 [==============================] - 14s 355ms/step - loss: 0.8946 - accuracy: 0.6021 - precision: 0.6478 - recall: 0.5140 - val_loss: 0.8714 - val_accuracy: 0.6234 - val_precision: 0.6837 - val_recall: 0.5207
# Epoch 10/50
# 40/40 [==============================] - 14s 362ms/step - loss: 0.9001 - accuracy: 0.5998 - precision: 0.6499 - recall: 0.5092 - val_loss: 0.8726 - val_accuracy: 0.6234 - val_precision: 0.6853 - val_recall: 0.5218
# Epoch 11/50
# 40/40 [==============================] - 14s 360ms/step - loss: 0.9021 - accuracy: 0.6021 - precision: 0.6434 - recall: 0.5033 - val_loss: 0.8691 - val_accuracy: 0.6234 - val_precision: 0.6770 - val_recall: 0.5396
# Epoch 12/50
# 40/40 [==============================] - 14s 341ms/step - loss: 0.9014 - accuracy: 0.6013 - precision: 0.6483 - recall: 0.5085 - val_loss: 0.8692 - val_accuracy: 0.6246 - val_precision: 0.6802 - val_recall: 0.5325
# Epoch 13/50
# 40/40 [==============================] - 14s 361ms/step - loss: 0.8998 - accuracy: 0.6002 - precision: 0.6419 - recall: 0.5092 - val_loss: 0.8673 - val_accuracy: 0.6234 - val_precision: 0.6792 - val_recall: 0.5325
# Epoch 14/50
# 40/40 [==============================] - 14s 339ms/step - loss: 0.8957 - accuracy: 0.6033 - precision: 0.6498 - recall: 0.5148 - val_loss: 0.8701 - val_accuracy: 0.6187 - val_precision: 0.6756 - val_recall: 0.5360
# Epoch 15/50
# 40/40 [==============================] - 12s 309ms/step - loss: 0.8933 - accuracy: 0.6116 - precision: 0.6490 - recall: 0.5144 - val_loss: 0.8692 - val_accuracy: 0.6187 - val_precision: 0.6730 - val_recall: 0.5443
# Epoch 16/50
# 40/40 [==============================] - 13s 335ms/step - loss: 0.8968 - accuracy: 0.6068 - precision: 0.6451 - recall: 0.5230 - val_loss: 0.8680 - val_accuracy: 0.6328 - val_precision: 0.6798 - val_recall: 0.5289
# Epoch 17/50
# 40/40 [==============================] - 14s 357ms/step - loss: 0.8890 - accuracy: 0.6045 - precision: 0.6527 - recall: 0.5266 - val_loss: 0.8724 - val_accuracy: 0.6187 - val_precision: 0.6732 - val_recall: 0.5277
# Epoch 18/50
# 40/40 [==============================] - 17s 429ms/step - loss: 0.8927 - accuracy: 0.6088 - precision: 0.6466 - recall: 0.5207 - val_loss: 0.8744 - val_accuracy: 0.6222 - val_precision: 0.6584 - val_recall: 0.5620
# Epoch 19/50
# 40/40 [==============================] - 16s 390ms/step - loss: 0.8892 - accuracy: 0.6108 - precision: 0.6508 - recall: 0.5258 - val_loss: 0.8692 - val_accuracy: 0.6222 - val_precision: 0.6763 - val_recall: 0.5254
# Epoch 20/50
# 40/40 [==============================] - 12s 307ms/step - loss: 0.8898 - accuracy: 0.6057 - precision: 0.6449 - recall: 0.5246 - val_loss: 0.8682 - val_accuracy: 0.6316 - val_precision: 0.6824 - val_recall: 0.5277
# Epoch 21/50
# 40/40 [==============================] - 12s 306ms/step - loss: 0.8890 - accuracy: 0.6080 - precision: 0.6452 - recall: 0.5211 - val_loss: 0.8745 - val_accuracy: 0.6269 - val_precision: 0.6717 - val_recall: 0.5266
# Epoch 22/50
# 40/40 [==============================] - 16s 396ms/step - loss: 0.8896 - accuracy: 0.6065 - precision: 0.6496 - recall: 0.5340 - val_loss: 0.8685 - val_accuracy: 0.6328 - val_precision: 0.6809 - val_recall: 0.5266
# Epoch 23/50
# 40/40 [==============================] - 14s 359ms/step - loss: 0.8882 - accuracy: 0.6124 - precision: 0.6540 - recall: 0.5230 - val_loss: 0.8742 - val_accuracy: 0.6257 - val_precision: 0.6634 - val_recall: 0.5537
# Epoch 24/50
# 40/40 [==============================] - 18s 442ms/step - loss: 0.8846 - accuracy: 0.6139 - precision: 0.6457 - recall: 0.5329 - val_loss: 0.8817 - val_accuracy: 0.6281 - val_precision: 0.6942 - val_recall: 0.4664
# Epoch 25/50
# 40/40 [==============================] - 15s 376ms/step - loss: 0.8854 - accuracy: 0.6096 - precision: 0.6469 - recall: 0.5234 - val_loss: 0.8648 - val_accuracy: 0.6316 - val_precision: 0.6781 - val_recall: 0.5372
# Epoch 26/50
# 40/40 [==============================] - 14s 364ms/step - loss: 0.8845 - accuracy: 0.6147 - precision: 0.6518 - recall: 0.5274 - val_loss: 0.8646 - val_accuracy: 0.6328 - val_precision: 0.6657 - val_recall: 0.5549
# Epoch 27/50
# 40/40 [==============================] - 15s 363ms/step - loss: 0.8802 - accuracy: 0.6135 - precision: 0.6506 - recall: 0.5372 - val_loss: 0.8642 - val_accuracy: 0.6340 - val_precision: 0.6657 - val_recall: 0.5596
# Epoch 28/50
# 40/40 [==============================] - 14s 360ms/step - loss: 0.8818 - accuracy: 0.6112 - precision: 0.6495 - recall: 0.5376 - val_loss: 0.8618 - val_accuracy: 0.6316 - val_precision: 0.6860 - val_recall: 0.5313
# Epoch 29/50
# 40/40 [==============================] - 14s 362ms/step - loss: 0.8800 - accuracy: 0.6167 - precision: 0.6532 - recall: 0.5277 - val_loss: 0.8752 - val_accuracy: 0.6293 - val_precision: 0.6737 - val_recall: 0.5313
# Epoch 30/50
# 40/40 [==============================] - 14s 362ms/step - loss: 0.8771 - accuracy: 0.6139 - precision: 0.6530 - recall: 0.5340 - val_loss: 0.8752 - val_accuracy: 0.6305 - val_precision: 0.6556 - val_recall: 0.5620
# Epoch 31/50
# 40/40 [==============================] - 15s 364ms/step - loss: 0.8830 - accuracy: 0.6128 - precision: 0.6455 - recall: 0.5317 - val_loss: 0.8695 - val_accuracy: 0.6316 - val_precision: 0.6701 - val_recall: 0.5372
# Epoch 32/50
# 40/40 [==============================] - 15s 373ms/step - loss: 0.8802 - accuracy: 0.6167 - precision: 0.6430 - recall: 0.5317 - val_loss: 0.8623 - val_accuracy: 0.6316 - val_precision: 0.6728 - val_recall: 0.5608
# Epoch 33/50
# 40/40 [==============================] - 15s 371ms/step - loss: 0.8760 - accuracy: 0.6190 - precision: 0.6501 - recall: 0.5309 - val_loss: 0.8610 - val_accuracy: 0.6364 - val_precision: 0.6808 - val_recall: 0.5136
# Epoch 34/50
# 40/40 [==============================] - 15s 378ms/step - loss: 0.8795 - accuracy: 0.6116 - precision: 0.6522 - recall: 0.5380 - val_loss: 0.8671 - val_accuracy: 0.6340 - val_precision: 0.6597 - val_recall: 0.5584
# Epoch 35/50
# 40/40 [==============================] - 15s 370ms/step - loss: 0.8771 - accuracy: 0.6151 - precision: 0.6462 - recall: 0.5392 - val_loss: 0.8578 - val_accuracy: 0.6364 - val_precision: 0.6724 - val_recall: 0.5573
# Epoch 36/50
# 40/40 [==============================] - 15s 368ms/step - loss: 0.8731 - accuracy: 0.6179 - precision: 0.6525 - recall: 0.5396 - val_loss: 0.8579 - val_accuracy: 0.6352 - val_precision: 0.6793 - val_recall: 0.5502
# Epoch 37/50
# 40/40 [==============================] - 15s 373ms/step - loss: 0.8746 - accuracy: 0.6202 - precision: 0.6562 - recall: 0.5521 - val_loss: 0.8620 - val_accuracy: 0.6316 - val_precision: 0.6747 - val_recall: 0.5289
# Epoch 38/50
# 40/40 [==============================] - 15s 369ms/step - loss: 0.8736 - accuracy: 0.6179 - precision: 0.6553 - recall: 0.5431 - val_loss: 0.8581 - val_accuracy: 0.6352 - val_precision: 0.6691 - val_recall: 0.5490
# Epoch 39/50
# 40/40 [==============================] - 15s 373ms/step - loss: 0.8696 - accuracy: 0.6135 - precision: 0.6545 - recall: 0.5360 - val_loss: 0.8588 - val_accuracy: 0.6352 - val_precision: 0.6780 - val_recall: 0.5396
# Epoch 40/50
# 40/40 [==============================] - 15s 363ms/step - loss: 0.8655 - accuracy: 0.6210 - precision: 0.6540 - recall: 0.5490 - val_loss: 0.8598 - val_accuracy: 0.6352 - val_precision: 0.6774 - val_recall: 0.5230
# Epoch 41/50
# 40/40 [==============================] - 14s 361ms/step - loss: 0.8748 - accuracy: 0.6167 - precision: 0.6537 - recall: 0.5356 - val_loss: 0.8518 - val_accuracy: 0.6411 - val_precision: 0.6811 - val_recall: 0.5573
# Epoch 42/50
# 40/40 [==============================] - 14s 363ms/step - loss: 0.8687 - accuracy: 0.6187 - precision: 0.6529 - recall: 0.5396 - val_loss: 0.8559 - val_accuracy: 0.6281 - val_precision: 0.6814 - val_recall: 0.5478
# Epoch 43/50
# 40/40 [==============================] - 15s 367ms/step - loss: 0.8666 - accuracy: 0.6175 - precision: 0.6526 - recall: 0.5580 - val_loss: 0.8538 - val_accuracy: 0.6352 - val_precision: 0.6852 - val_recall: 0.5396
# Epoch 44/50
# 40/40 [==============================] - 15s 364ms/step - loss: 0.8690 - accuracy: 0.6179 - precision: 0.6576 - recall: 0.5336 - val_loss: 0.8601 - val_accuracy: 0.6375 - val_precision: 0.6733 - val_recall: 0.5573
# Epoch 45/50
# 40/40 [==============================] - 14s 360ms/step - loss: 0.8796 - accuracy: 0.6151 - precision: 0.6506 - recall: 0.5561 - val_loss: 0.8585 - val_accuracy: 0.6387 - val_precision: 0.6821 - val_recall: 0.5573
# Epoch 46/50
# 40/40 [==============================] - 15s 377ms/step - loss: 0.8671 - accuracy: 0.6187 - precision: 0.6607 - recall: 0.5403 - val_loss: 0.8558 - val_accuracy: 0.6364 - val_precision: 0.6765 - val_recall: 0.5431
# Epoch 47/50
# 40/40 [==============================] - 15s 386ms/step - loss: 0.8627 - accuracy: 0.6218 - precision: 0.6581 - recall: 0.5521 - val_loss: 0.8591 - val_accuracy: 0.6316 - val_precision: 0.6710 - val_recall: 0.5466
# Epoch 48/50
# 40/40 [==============================] - 16s 398ms/step - loss: 0.8672 - accuracy: 0.6187 - precision: 0.6515 - recall: 0.5482 - val_loss: 0.8590 - val_accuracy: 0.6411 - val_precision: 0.6622 - val_recall: 0.5785
# Epoch 49/50
# 40/40 [==============================] - 16s 394ms/step - loss: 0.8638 - accuracy: 0.6250 - precision: 0.6541 - recall: 0.5478 - val_loss: 0.8545 - val_accuracy: 0.6375 - val_precision: 0.6845 - val_recall: 0.5301
# Epoch 50/50
# 40/40 [==============================] - 16s 392ms/step - loss: 0.8656 - accuracy: 0.6230 - precision: 0.6570 - recall: 0.5368 - val_loss: 0.8553 - val_accuracy: 0.6399 - val_precision: 0.6799 - val_recall: 0.5667

# %% [markdown]
# ### Model Accuracy & Loss

# %%
# Evaluate model on the test set
loss, accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Accuracy  : 0.6185
# Precision : 0.6485
# Recall    : 0.5413
# F1 Score  : 0.5901

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''
    
    fig, ax = plt.subplots(1, 2, figsize=(15,7))
    # first plot
    ax[0].plot(history.history['accuracy'])
    ax[0].plot(history.history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history.history['loss'])
    ax[1].plot(history.history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')
    
plot_training_hist(history)

# %% [markdown]
# ### Model Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''
    
    sentiment_classes = ['Negative', 'Neutral', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test),axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(15,10))
    sns.heatmap(cm, cmap="BuPu", annot=True, fmt='d', 
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    #plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('\nPredicted label', fontsize=14)
    plt.ylabel('Actual label\n', fontsize=14)
    
plot_confusion_matrix(model, X_test, y_test)

# %% [markdown]
# # NN update with early stopping

# %% [markdown]
# NN is overfitting, we can apply early stops to overcome the problem

# %%
es = EarlyStopping(monitor='val_loss', patience=10)
history_es = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, 
                      batch_size=64, callbacks=[es]).history
# Out:
# Epoch 1/50
# 40/40 [==============================] - 15s 362ms/step - loss: 0.8618 - accuracy: 0.6214 - precision: 0.6558 - recall: 0.5451 - val_loss: 0.8540 - val_accuracy: 0.6340 - val_precision: 0.6779 - val_recall: 0.5466
# Epoch 2/50
# 40/40 [==============================] - 20s 498ms/step - loss: 0.8611 - accuracy: 0.6179 - precision: 0.6567 - recall: 0.5384 - val_loss: 0.8553 - val_accuracy: 0.6387 - val_precision: 0.6701 - val_recall: 0.5372
# Epoch 3/50
# 40/40 [==============================] - 17s 439ms/step - loss: 0.8620 - accuracy: 0.6238 - precision: 0.6588 - recall: 0.5462 - val_loss: 0.8528 - val_accuracy: 0.6411 - val_precision: 0.6747 - val_recall: 0.5608
# Epoch 4/50
# 40/40 [==============================] - 15s 388ms/step - loss: 0.8622 - accuracy: 0.6246 - precision: 0.6504 - recall: 0.5447 - val_loss: 0.8681 - val_accuracy: 0.6364 - val_precision: 0.6695 - val_recall: 0.5643
# Epoch 5/50
# 40/40 [==============================] - 15s 374ms/step - loss: 0.8816 - accuracy: 0.6120 - precision: 0.6490 - recall: 0.5494 - val_loss: 0.8826 - val_accuracy: 0.6151 - val_precision: 0.6615 - val_recall: 0.5490
# Epoch 6/50
# 40/40 [==============================] - 15s 384ms/step - loss: 0.8787 - accuracy: 0.6128 - precision: 0.6480 - recall: 0.5238 - val_loss: 0.8661 - val_accuracy: 0.6340 - val_precision: 0.6710 - val_recall: 0.5466
# Epoch 7/50
# 40/40 [==============================] - 14s 356ms/step - loss: 0.8735 - accuracy: 0.6167 - precision: 0.6513 - recall: 0.5462 - val_loss: 0.8625 - val_accuracy: 0.6364 - val_precision: 0.6713 - val_recall: 0.5667
# Epoch 8/50
# 40/40 [==============================] - 16s 412ms/step - loss: 0.8717 - accuracy: 0.6222 - precision: 0.6579 - recall: 0.5427 - val_loss: 0.8673 - val_accuracy: 0.6293 - val_precision: 0.6647 - val_recall: 0.5360
# Epoch 9/50
# 40/40 [==============================] - 15s 364ms/step - loss: 0.8685 - accuracy: 0.6214 - precision: 0.6538 - recall: 0.5352 - val_loss: 0.8755 - val_accuracy: 0.6210 - val_precision: 0.6583 - val_recall: 0.5549
# Epoch 10/50
# 40/40 [==============================] - 15s 385ms/step - loss: 0.8670 - accuracy: 0.6210 - precision: 0.6530 - recall: 0.5466 - val_loss: 0.8669 - val_accuracy: 0.6293 - val_precision: 0.6662 - val_recall: 0.5584
# Epoch 11/50
# 40/40 [==============================] - 13s 336ms/step - loss: 0.8700 - accuracy: 0.6210 - precision: 0.6515 - recall: 0.5458 - val_loss: 0.8660 - val_accuracy: 0.6328 - val_precision: 0.6657 - val_recall: 0.5455
# Epoch 12/50
# 40/40 [==============================] - 17s 433ms/step - loss: 0.8652 - accuracy: 0.6167 - precision: 0.6602 - recall: 0.5360 - val_loss: 0.8649 - val_accuracy: 0.6328 - val_precision: 0.6618 - val_recall: 0.5407
# Epoch 13/50
# 40/40 [==============================] - 13s 336ms/step - loss: 0.8638 - accuracy: 0.6179 - precision: 0.6513 - recall: 0.5490 - val_loss: 0.8653 - val_accuracy: 0.6352 - val_precision: 0.6610 - val_recall: 0.5549

# %%
# Evaluate model on the test set
loss, accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Print metrics
print('')
print('Accuracy  : {:.4f}'.format(accuracy))
print('Precision : {:.4f}'.format(precision))
print('Recall    : {:.4f}'.format(recall))
print('F1 Score  : {:.4f}'.format(f1_score(precision, recall)))
# Out:
# Accuracy  : 0.6191
# Precision : 0.6427
# Recall    : 0.5303
# F1 Score  : 0.5811

# %%
def plot_training_hist(history):
    '''Function to plot history for accuracy and loss'''
    
    fig, ax = plt.subplots(1, 2, figsize=(15,7))
    # first plot
    ax[0].plot(history['accuracy'])
    ax[0].plot(history['val_accuracy'])
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('accuracy')
    ax[0].legend(['train', 'validation'], loc='best')
    # second plot
    ax[1].plot(history['loss'])
    ax[1].plot(history['val_loss'])
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('loss')
    ax[1].legend(['train', 'validation'], loc='best')
    
plot_training_hist(history_es)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(model, X_test, y_test):
    '''Function to plot confusion matrix for the passed model and the data'''
    
    sentiment_classes = ['Negative', 'Neutral', 'Positive']
    # use model to do the prediction
    y_pred = model.predict(X_test)
    # compute confusion matrix
    cm = confusion_matrix(np.argmax(np.array(y_test),axis=1), np.argmax(y_pred, axis=1))
    # plot confusion matrix
    plt.figure(figsize=(15,10))
    sns.heatmap(cm, cmap="BuPu", annot=True, fmt='d', 
                xticklabels=sentiment_classes,
                yticklabels=sentiment_classes)
    plt.title('Confusion matrix', fontsize=16)
    plt.xlabel('\nPredicted label', fontsize=14)
    plt.ylabel('Actual label\n', fontsize=14)
    
plot_confusion_matrix(model, X_test, y_test)
